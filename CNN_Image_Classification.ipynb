# %% [markdown]
# <a href="https://colab.research.google.com/github/R4HUL-ROY/Deep_Learning/blob/main/CNN_Image_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
(X_train , y_train), (X_test, y_test) = datasets.cifar10.load_data()

# %%
import cv2
from google.colab.patches import cv2_imshow
cv2_imshow(cv2.resize(X_train[1], (200, 200)))
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FF1AFEB03D0>

# %%
X_train = X_train / 255
X_test = X_test / 255

# %%
cnn = models.Sequential([
    layers.Conv2D(filters = 32, activation='relu', kernel_size=(3,3) , input_shape = (32,32,3)),
    layers.MaxPooling2D((2,2)),

    layers.Conv2D(filters = 64, activation='relu', kernel_size=(3,3)),
    layers.MaxPooling2D((2,2)),

    layers.Flatten(),
    layers.Dense(units = 64, activation = 'relu'),
    layers.Dense(units = 10, activation = 'softmax')
])

# %%
cnn.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy'   , metrics = ['accuracy'])

# %%
cnn.fit(X_train, y_train, epochs = 50)
# Out:
# Epoch 1/50
# 1563/1563 [==============================] - 19s 6ms/step - loss: 1.4615 - accuracy: 0.4703
# Epoch 2/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 1.1048 - accuracy: 0.6119
# Epoch 3/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.9775 - accuracy: 0.6587
# Epoch 4/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8897 - accuracy: 0.6897
# Epoch 5/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.8267 - accuracy: 0.7117
# Epoch 6/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7680 - accuracy: 0.7330
# Epoch 7/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.7188 - accuracy: 0.7489
# Epoch 8/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6727 - accuracy: 0.7630
# Epoch 9/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6357 - accuracy: 0.7773
# Epoch 10/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.6005 - accuracy: 0.7902
# Epoch 11/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5649 - accuracy: 0.8029
# Epoch 12/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5315 - accuracy: 0.8134
# Epoch 13/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.5033 - accuracy: 0.8211
# Epoch 14/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4753 - accuracy: 0.8319
# Epoch 15/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4552 - accuracy: 0.8392
# Epoch 16/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.4281 - accuracy: 0.8488
# Epoch 17/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.4090 - accuracy: 0.8552
# Epoch 18/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3831 - accuracy: 0.8644
# Epoch 19/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3627 - accuracy: 0.8705
# Epoch 20/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3419 - accuracy: 0.8775
# Epoch 21/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3264 - accuracy: 0.8830
# Epoch 22/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.3109 - accuracy: 0.8903
# Epoch 23/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2949 - accuracy: 0.8941
# Epoch 24/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2709 - accuracy: 0.9026
# Epoch 25/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2590 - accuracy: 0.9066
# Epoch 26/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2475 - accuracy: 0.9111
# Epoch 27/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2316 - accuracy: 0.9175
# Epoch 28/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2241 - accuracy: 0.9189
# Epoch 29/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.2063 - accuracy: 0.9251
# Epoch 30/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1994 - accuracy: 0.9275
# Epoch 31/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1958 - accuracy: 0.9298
# Epoch 32/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1789 - accuracy: 0.9359
# Epoch 33/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1792 - accuracy: 0.9363
# Epoch 34/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1653 - accuracy: 0.9404
# Epoch 35/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1652 - accuracy: 0.9403
# Epoch 36/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1584 - accuracy: 0.9438
# Epoch 37/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1510 - accuracy: 0.9449
# Epoch 38/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1428 - accuracy: 0.9492
# Epoch 39/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1428 - accuracy: 0.9491
# Epoch 40/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1374 - accuracy: 0.9509
# Epoch 41/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1228 - accuracy: 0.9558
# Epoch 42/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1256 - accuracy: 0.9547
# Epoch 43/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1249 - accuracy: 0.9554
# Epoch 44/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1257 - accuracy: 0.9558
# Epoch 45/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1156 - accuracy: 0.9581
# Epoch 46/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1182 - accuracy: 0.9583
# Epoch 47/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1096 - accuracy: 0.9621
# Epoch 48/50
# 1563/1563 [==============================] - 10s 7ms/step - loss: 0.1107 - accuracy: 0.9599
# Epoch 49/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1080 - accuracy: 0.9616
# Epoch 50/50
# 1563/1563 [==============================] - 10s 6ms/step - loss: 0.1057 - accuracy: 0.9628

# %%
cnn.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 2s 4ms/step - loss: 2.8791 - accuracy: 0.6642
# [2.8790972232818604, 0.6642000079154968]
