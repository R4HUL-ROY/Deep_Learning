# %% [markdown]
# <a href="https://colab.research.google.com/github/R4HUL-ROY/Deep_Learning/blob/main/MLP_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /usr/local/lib/python3.7/dist-packages (1.1.0)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.7.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.19.5)
# Requirement already satisfied: kt-legacy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.0.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (2.23.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (5.5.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from keras-tuner) (21.3)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (1.0.18)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (57.4.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->keras-tuner) (0.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (0.2.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->keras-tuner) (1.15.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->keras-tuner) (3.0.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->keras-tuner) (1.24.3)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.37.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.17.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.42.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard->keras-tuner) (1.8.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard->keras-tuner) (4.8.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard->keras-tuner) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->keras-tuner) (3.1.1)

# %%
df = pd.read_csv('/content/drive/MyDrive/Machine Learning/ML DATASET/diabetes.csv')
df
# Out:
#      Pregnancies  Glucose  ...  Age  Outcome
# 0              6      148  ...   50        1
# 1              1       85  ...   31        0
# 2              8      183  ...   32        1
# 3              1       89  ...   21        0
# 4              0      137  ...   33        1
# ..           ...      ...  ...  ...      ...
# 763           10      101  ...   63        0
# 764            2      122  ...   27        0
# 765            5      121  ...   30        0
# 766            1      126  ...   47        1
# 767            1       93  ...   23        0
#
# [768 rows x 9 columns]

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from tensorflow import keras
from keras.models import Sequential
from keras.layers import *
import keras_tuner as kt
from keras.layers import Dropout
from tensorflow.keras.optimizers import Adam

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(keras.layers.Flatten(input_shape=(8,)))
    for i in range(hp.Int('num_layers', 2, 20)):
        model.add(Dense(units=hp.Int('units_' + str(i),min_value=1, max_value=512,step=8) ,activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(optimizer=tf.keras.optimizers.Adam(hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4])), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
tuner = kt.RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory='project',
    project_name='diabetes_prediction')

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 4
# num_layers (Int)
# {'default': None, 'conditions': [], 'min_value': 2, 'max_value': 20, 'step': 1, 'sampling': None}
# units_0 (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 512, 'step': 8, 'sampling': None}
# units_1 (Int)
# {'default': None, 'conditions': [], 'min_value': 1, 'max_value': 512, 'step': 8, 'sampling': None}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x , y, test_size=0.2, random_state = 0)

# %%
scaler = MinMaxScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
tuner.search(x_train_scaled, y_train,
             epochs=100,
             validation_data=(x_test_scaled, y_test))
# Out:
# Trial 5 Complete [00h 00m 32s]
# val_accuracy: 0.766233762105306
#
# Best val_accuracy So Far: 0.8116883039474487
# Total elapsed time: 00h 06m 30s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# Results summary
# Results in project/diabetes_prediction
# Showing 10 best trials
# Objective(name='val_accuracy', direction='max')
# Trial summary
# Hyperparameters:
# num_layers: 5
# units_0: 17
# units_1: 17
# learning_rate: 0.0001
# units_2: 497
# units_3: 433
# units_4: 273
# units_5: 441
# units_6: 305
# units_7: 329
# units_8: 337
# units_9: 113
# units_10: 481
# Score: 0.8116883039474487
# Trial summary
# Hyperparameters:
# num_layers: 10
# units_0: 81
# units_1: 305
# learning_rate: 0.0001
# units_2: 409
# units_3: 153
# units_4: 369
# units_5: 41
# units_6: 281
# units_7: 313
# units_8: 201
# units_9: 33
# units_10: 161
# Score: 0.8008657892545065
# Trial summary
# Hyperparameters:
# num_layers: 3
# units_0: 265
# units_1: 1
# learning_rate: 0.001
# units_2: 97
# units_3: 337
# units_4: 393
# units_5: 409
# units_6: 337
# units_7: 169
# units_8: 481
# units_9: 193
# units_10: 329
# units_11: 257
# units_12: 17
# units_13: 289
# units_14: 393
# Score: 0.766233762105306
# Trial summary
# Hyperparameters:
# num_layers: 11
# units_0: 257
# units_1: 193
# learning_rate: 0.01
# units_2: 1
# units_3: 1
# units_4: 1
# units_5: 1
# units_6: 1
# units_7: 1
# units_8: 1
# units_9: 1
# units_10: 1
# Score: 0.6948052048683167
# Trial summary
# Hyperparameters:
# num_layers: 15
# units_0: 73
# units_1: 369
# learning_rate: 0.0001
# units_2: 57
# units_3: 121
# units_4: 465
# units_5: 249
# units_6: 241
# units_7: 481
# units_8: 17
# units_9: 337
# units_10: 297
# units_11: 1
# units_12: 1
# units_13: 1
# units_14: 1
# Score: 0.6948052048683167

# %%
classifier = Sequential()

classifier.add(Dense(units = 312, kernel_initializer= 'he_uniform', activation='relu' , input_shape=(8,)))
classifier.add(Dropout(0.3))

classifier.add(Dense(units = 488, kernel_initializer= 'he_uniform', activation='relu'))
classifier.add(Dropout(0.4))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))

classifier.add(Dense(units = 16, kernel_initializer= 'he_uniform', activation='relu'))


classifier.add(Dense(units = 1, kernel_initializer= 'glorot_uniform', activation = 'sigmoid'))

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 312)               2808
#
#  dropout (Dropout)           (None, 312)               0
#
#  dense_5 (Dense)             (None, 488)               152744
#
#  dropout_1 (Dropout)         (None, 488)               0
#
#  dense_6 (Dense)             (None, 16)                7824
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 16)                272
#
#  dense_9 (Dense)             (None, 16)                272
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 16)                272
#
#  dense_12 (Dense)            (None, 16)                272
#
#  dense_13 (Dense)            (None, 16)                272
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 165,297
# Trainable params: 165,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
classifier.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'] )
model_history = classifier.fit(x_train_scaled, y_train, batch_size = 10, epochs = 200)
# Out:
# Epoch 1/200
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 62/62 [==============================] - 1s 6ms/step - loss: 0.6916 - accuracy: 0.5195
# Epoch 2/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6874 - accuracy: 0.6075
# Epoch 3/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6731 - accuracy: 0.6336
# Epoch 4/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6751 - accuracy: 0.6107
# Epoch 5/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6614 - accuracy: 0.6352
# Epoch 6/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6621 - accuracy: 0.6384
# Epoch 7/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6603 - accuracy: 0.6384
# Epoch 8/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.6221
# Epoch 9/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6461 - accuracy: 0.6352
# Epoch 10/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6484 - accuracy: 0.6482
# Epoch 11/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6438 - accuracy: 0.6433
# Epoch 12/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6377 - accuracy: 0.6482
# Epoch 13/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6281 - accuracy: 0.6531
# Epoch 14/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6322 - accuracy: 0.6482
# Epoch 15/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6360 - accuracy: 0.6384
# Epoch 16/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6153 - accuracy: 0.6482
# Epoch 17/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6109 - accuracy: 0.6531
# Epoch 18/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6128 - accuracy: 0.6547
# Epoch 19/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6078 - accuracy: 0.6450
# Epoch 20/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6143 - accuracy: 0.6417
# Epoch 21/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6121 - accuracy: 0.6678
# Epoch 22/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.6088 - accuracy: 0.6775
# Epoch 23/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6108 - accuracy: 0.6498
# Epoch 24/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6078 - accuracy: 0.6678
# Epoch 25/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6056 - accuracy: 0.6629
# Epoch 26/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5942 - accuracy: 0.6629
# Epoch 27/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5887 - accuracy: 0.6840
# Epoch 28/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5960 - accuracy: 0.6629
# Epoch 29/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5998 - accuracy: 0.6661
# Epoch 30/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5972 - accuracy: 0.6661
# Epoch 31/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5996 - accuracy: 0.6547
# Epoch 32/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5944 - accuracy: 0.6710
# Epoch 33/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5825 - accuracy: 0.6840
# Epoch 34/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5757 - accuracy: 0.6906
# Epoch 35/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5920 - accuracy: 0.6743
# Epoch 36/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5836 - accuracy: 0.6873
# Epoch 37/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.6000 - accuracy: 0.6596
# Epoch 38/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5751 - accuracy: 0.6922
# Epoch 39/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5693 - accuracy: 0.6775
# Epoch 40/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5735 - accuracy: 0.6857
# Epoch 41/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5696 - accuracy: 0.6889
# Epoch 42/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5880 - accuracy: 0.6824
# Epoch 43/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5805 - accuracy: 0.6857
# Epoch 44/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5724 - accuracy: 0.6873
# Epoch 45/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5772 - accuracy: 0.6906
# Epoch 46/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5760 - accuracy: 0.6792
# Epoch 47/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5599 - accuracy: 0.6922
# Epoch 48/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5717 - accuracy: 0.6906
# Epoch 49/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5634 - accuracy: 0.6987
# Epoch 50/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5616 - accuracy: 0.7020
# Epoch 51/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5586 - accuracy: 0.6873
# Epoch 52/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5690 - accuracy: 0.6938
# Epoch 53/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5569 - accuracy: 0.7101
# Epoch 54/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5577 - accuracy: 0.7085
# Epoch 55/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5450 - accuracy: 0.7101
# Epoch 56/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5449 - accuracy: 0.7101
# Epoch 57/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5543 - accuracy: 0.6954
# Epoch 58/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5449 - accuracy: 0.7134
# Epoch 59/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5552 - accuracy: 0.7020
# Epoch 60/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5662 - accuracy: 0.6873
# Epoch 61/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5465 - accuracy: 0.6889
# Epoch 62/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5474 - accuracy: 0.7166
# Epoch 63/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5579 - accuracy: 0.7085
# Epoch 64/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5561 - accuracy: 0.7117
# Epoch 65/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5456 - accuracy: 0.7150
# Epoch 66/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5479 - accuracy: 0.6938
# Epoch 67/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5386 - accuracy: 0.7182
# Epoch 68/200
# 62/62 [==============================] - 1s 8ms/step - loss: 0.5520 - accuracy: 0.7085
# Epoch 69/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5284 - accuracy: 0.7231
# Epoch 70/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5436 - accuracy: 0.7101
# Epoch 71/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5446 - accuracy: 0.7182
# Epoch 72/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5357 - accuracy: 0.7199
# Epoch 73/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5368 - accuracy: 0.7085
# Epoch 74/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5216 - accuracy: 0.7443
# Epoch 75/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.7378
# Epoch 76/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5310 - accuracy: 0.7134
# Epoch 77/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5330 - accuracy: 0.7410
# Epoch 78/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5332 - accuracy: 0.7296
# Epoch 79/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5324 - accuracy: 0.7345
# Epoch 80/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5226 - accuracy: 0.7345
# Epoch 81/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5252 - accuracy: 0.7264
# Epoch 82/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5408 - accuracy: 0.7296
# Epoch 83/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5450 - accuracy: 0.7199
# Epoch 84/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5265 - accuracy: 0.7280
# Epoch 85/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5146 - accuracy: 0.7524
# Epoch 86/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5208 - accuracy: 0.7427
# Epoch 87/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5158 - accuracy: 0.7231
# Epoch 88/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5312 - accuracy: 0.7280
# Epoch 89/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5186 - accuracy: 0.7264
# Epoch 90/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5277 - accuracy: 0.7329
# Epoch 91/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5177 - accuracy: 0.7459
# Epoch 92/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5305 - accuracy: 0.7345
# Epoch 93/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5236 - accuracy: 0.7329
# Epoch 94/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5338 - accuracy: 0.7378
# Epoch 95/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5150 - accuracy: 0.7459
# Epoch 96/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5168 - accuracy: 0.7443
# Epoch 97/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5203 - accuracy: 0.7150
# Epoch 98/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5005 - accuracy: 0.7590
# Epoch 99/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5074 - accuracy: 0.7427
# Epoch 100/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5112 - accuracy: 0.7573
# Epoch 101/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5123 - accuracy: 0.7296
# Epoch 102/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5047 - accuracy: 0.7492
# Epoch 103/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4948 - accuracy: 0.7492
# Epoch 104/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5118 - accuracy: 0.7378
# Epoch 105/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5118 - accuracy: 0.7557
# Epoch 106/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5172 - accuracy: 0.7231
# Epoch 107/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5201 - accuracy: 0.7378
# Epoch 108/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4917 - accuracy: 0.7622
# Epoch 109/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.5075 - accuracy: 0.7362
# Epoch 110/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5081 - accuracy: 0.7362
# Epoch 111/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4967 - accuracy: 0.7541
# Epoch 112/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5024 - accuracy: 0.7443
# Epoch 113/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4981 - accuracy: 0.7508
# Epoch 114/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4945 - accuracy: 0.7459
# Epoch 115/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4965 - accuracy: 0.7394
# Epoch 116/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4924 - accuracy: 0.7508
# Epoch 117/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4966 - accuracy: 0.7606
# Epoch 118/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4967 - accuracy: 0.7606
# Epoch 119/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4993 - accuracy: 0.7557
# Epoch 120/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5058 - accuracy: 0.7492
# Epoch 121/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4989 - accuracy: 0.7476
# Epoch 122/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4990 - accuracy: 0.7687
# Epoch 123/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4806 - accuracy: 0.7655
# Epoch 124/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4956 - accuracy: 0.7508
# Epoch 125/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4995 - accuracy: 0.7573
# Epoch 126/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4766 - accuracy: 0.7720
# Epoch 127/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4916 - accuracy: 0.7622
# Epoch 128/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4904 - accuracy: 0.7704
# Epoch 129/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4824 - accuracy: 0.7704
# Epoch 130/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4780 - accuracy: 0.7622
# Epoch 131/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4754 - accuracy: 0.7752
# Epoch 132/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4851 - accuracy: 0.7590
# Epoch 133/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4872 - accuracy: 0.7476
# Epoch 134/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4838 - accuracy: 0.7720
# Epoch 135/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4899 - accuracy: 0.7606
# Epoch 136/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4757 - accuracy: 0.7606
# Epoch 137/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4689 - accuracy: 0.7736
# Epoch 138/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4913 - accuracy: 0.7720
# Epoch 139/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4962 - accuracy: 0.7687
# Epoch 140/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4761 - accuracy: 0.7622
# Epoch 141/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4802 - accuracy: 0.7769
# Epoch 142/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.5014 - accuracy: 0.7492
# Epoch 143/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4820 - accuracy: 0.7769
# Epoch 144/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4814 - accuracy: 0.7590
# Epoch 145/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4678 - accuracy: 0.7541
# Epoch 146/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4945 - accuracy: 0.7638
# Epoch 147/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4676 - accuracy: 0.7752
# Epoch 148/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4787 - accuracy: 0.7622
# Epoch 149/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4621 - accuracy: 0.7801
# Epoch 150/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4891 - accuracy: 0.7573
# Epoch 151/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4631 - accuracy: 0.7801
# Epoch 152/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4835 - accuracy: 0.7622
# Epoch 153/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4670 - accuracy: 0.7785
# Epoch 154/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4736 - accuracy: 0.7655
# Epoch 155/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4933 - accuracy: 0.7459
# Epoch 156/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4736 - accuracy: 0.7736
# Epoch 157/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4607 - accuracy: 0.7769
# Epoch 158/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4901 - accuracy: 0.7769
# Epoch 159/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4751 - accuracy: 0.7785
# Epoch 160/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4738 - accuracy: 0.7736
# Epoch 161/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4530 - accuracy: 0.7899
# Epoch 162/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4715 - accuracy: 0.7785
# Epoch 163/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4702 - accuracy: 0.7850
# Epoch 164/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4800 - accuracy: 0.7508
# Epoch 165/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4566 - accuracy: 0.7948
# Epoch 166/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4818 - accuracy: 0.7720
# Epoch 167/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4711 - accuracy: 0.7801
# Epoch 168/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4667 - accuracy: 0.7769
# Epoch 169/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4660 - accuracy: 0.7720
# Epoch 170/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4794 - accuracy: 0.7655
# Epoch 171/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4763 - accuracy: 0.7622
# Epoch 172/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4606 - accuracy: 0.7720
# Epoch 173/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4485 - accuracy: 0.7932
# Epoch 174/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4653 - accuracy: 0.7720
# Epoch 175/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4908 - accuracy: 0.7508
# Epoch 176/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4616 - accuracy: 0.7834
# Epoch 177/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4611 - accuracy: 0.7834
# Epoch 178/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4611 - accuracy: 0.7899
# Epoch 179/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4681 - accuracy: 0.7720
# Epoch 180/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4503 - accuracy: 0.7850
# Epoch 181/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4675 - accuracy: 0.7704
# Epoch 182/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4664 - accuracy: 0.7606
# Epoch 183/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4622 - accuracy: 0.7720
# Epoch 184/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4742 - accuracy: 0.7736
# Epoch 185/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4467 - accuracy: 0.8013
# Epoch 186/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4739 - accuracy: 0.7573
# Epoch 187/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4518 - accuracy: 0.7752
# Epoch 188/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4355 - accuracy: 0.8046
# Epoch 189/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4511 - accuracy: 0.7785
# Epoch 190/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4514 - accuracy: 0.7801
# Epoch 191/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4370 - accuracy: 0.7980
# Epoch 192/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4326 - accuracy: 0.7948
# Epoch 193/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4596 - accuracy: 0.7671
# Epoch 194/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4554 - accuracy: 0.7866
# Epoch 195/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4770 - accuracy: 0.7638
# Epoch 196/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.7752
# Epoch 197/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4559 - accuracy: 0.7769
# Epoch 198/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.4472 - accuracy: 0.8029
# Epoch 199/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4530 - accuracy: 0.7866
# Epoch 200/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4372 - accuracy: 0.7932

# %%
y_pred = classifier.predict(x_test_scaled)
y_pred = np.around(y_pred)

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

print(confusion_matrix(y_pred, y_test))
print(accuracy_score(y_pred, y_test))
# Out:
# [[93 22]
#  [14 25]]
# 0.7662337662337663
